# %% [markdown]
# ## PYTHON RAPPELS : LOI BINOMIALE ex 9 p. 438 ![icone python](https://upload.wikimedia.org/wikipedia/commons/0/0a/Python.svg)

# %%
def seuil(S):
    k=0
    P=0.95**80
    while P<S:
        k=k+1
        P=P+binomiale(k,80,0.38)
    return k

def binomiale(k,n,p):
    return(comb(k,n)*0.05**k*0.95**(n-k))


def comb(k,n):
    return((fact(n))/(fact(k)*fact(n-k)))

def fact(n):
    i=1
    resultat=1
    while i<n:
        i=i+1
        resultat=resultat*i
    return(resultat)

# %%
seuil(0.95)
# Out:
# 7

# %%
seuil(0.99)
# Out:
# 9

# %%
seuil(0.999)
# Out:
# 11
